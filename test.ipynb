# %%
import numpy as np
from bandits import MultiArmedBandits
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mab = MultiArmedBandits(stationery = True)

# %%
T = 5000
metrics = mab.run(T = T)
plt.plot(range(T), metrics['running_average_reward'])
plt.show()

# %%
plt.plot(range(T), metrics['optimal_action_rate'][0])
plt.show()
